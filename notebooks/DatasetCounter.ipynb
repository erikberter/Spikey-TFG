# %%
import os

# %%
os.walk("../datasets/HMDB51_Flow/train")
# Out:
# <generator object walk at 0x0000022132615A50>

# %%
next(os.walk("../datasets/HMDB51_Flow/train"))[1]
# Out:
# ['brush_hair',
#  'cartwheel',
#  'catch',
#  'chew',
#  'clap',
#  'climb',
#  'climb_stairs',
#  'dive',
#  'draw_sword',
#  'dribble',
#  'drink',
#  'eat',
#  'fall_floor',
#  'fencing',
#  'flic_flac',
#  'golf',
#  'handstand',
#  'hit',
#  'hug',
#  'jump',
#  'kick',
#  'kick_ball',
#  'kiss',
#  'laugh',
#  'pick',
#  'pour',
#  'pullup',
#  'punch',
#  'push',
#  'pushup',
#  'ride_bike',
#  'ride_horse',
#  'run',
#  'shake_hands',
#  'shoot_ball',
#  'shoot_bow',
#  'shoot_gun',
#  'sit',
#  'situp',
#  'smile',
#  'smoke',
#  'somersault',
#  'stand',
#  'swing_baseball',
#  'sword',
#  'sword_exercise',
#  'talk',
#  'throw',
#  'turn',
#  'walk',
#  'wave']

# %%
classes = next(os.walk("../datasets/UCF101_Flow/train"))[1]
sum_flow = 0
for i in classes:
    print(f"........{i}........")
    print(f"Flow Size", len(next(os.walk("../datasets/UCF101_Flow/train/"+i))[1]))
    print(f"Normal Size", len(next(os.walk("../datasets/UFC101/UCF101/Processed/train/"+i))[1]))
# Out:
# ........ApplyEyeMakeup........
# Flow Size 101
# Normal Size 101
# ........ApplyLipstick........
# Flow Size 82
# Normal Size 82
# ........Archery........
# Flow Size 104
# Normal Size 104
# ........BabyCrawling........
# Flow Size 97
# Normal Size 97
# ........BalanceBeam........
# Flow Size 77
# Normal Size 77
# ........BandMarching........
# Flow Size 112
# Normal Size 112
# ........BaseballPitch........
# Flow Size 107
# Normal Size 107
# ........Basketball........
# Flow Size 99
# Normal Size 99
# ........BasketballDunk........
# Flow Size 94
# Normal Size 94
# ........BenchPress........
# Flow Size 112
# Normal Size 112
# ........Biking........
# Flow Size 96
# Normal Size 96
# ........Billiards........
# Flow Size 110
# Normal Size 110
# ........BlowDryHair........
# Flow Size 93
# Normal Size 93
# ........BlowingCandles........
# Flow Size 76
# Normal Size 76
# ........BodyWeightSquats........
# Flow Size 82
# Normal Size 82
# ........Bowling........
# Flow Size 112
# ...
